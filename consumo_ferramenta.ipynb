# %% [markdown]
# # Análise Exploratória de Dados (EDA)

# %%
# importa biblioteca necessária para EDA
import pandas as pd

# %%
# importa os dados
df_producao = pd.read_parquet('tb_producao_consolidado.parquet') # importa os dados de produção
df_consumo_ferramentas = pd.read_parquet('tb_consumo_ferramentas_consolidado.parquet') # importa os dados de consumo de ferramentas

print('--- Informações: df_producao ---' + '\n') # exibe um descritivo do df
df_producao.info() # exibe o .info() do df

print('\n' + '-'*40 + '\n') # exibe um separador

print('--- Informações: df_consumo_ferramentas ---' + '\n') # exibe um descritivo do df
df_consumo_ferramentas.info() # exibe o .info() do df
# Out:
# --- Informações: df_producao ---
#
# <class 'pandas.DataFrame'>
# RangeIndex: 2941812 entries, 0 to 2941811
# Data columns (total 3 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Material          str
#  1   Qtd.boa confirm.  float64
#  2   Dt.lçto.          str
# dtypes: float64(1), str(2)
# memory usage: 119.2 MB
#
# ----------------------------------------
#
# --- Informações: df_consumo_ferramentas ---
#
# <class 'pandas.DataFrame'>
# RangeIndex: 166447 entries, 0 to 166446
# Data columns (total 3 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Material            166447 non-null  str
#  1   Qtd.  UM registro   166447 non-null  float64
#  2   Data de lançamento  166447 non-null  str
# dtypes: float64(1), str(2)
# memory usage: 7.3 MB

# %% [markdown]
# Não será necessário realiza limpeza de dados NA por conta do script 'consolidar_arquivos.py' já realiza essa operação durante a consolidação dos dados.

# %%
df_producao['Dt.lçto.'] = pd.to_datetime(df_producao['Dt.lçto.'])
df_consumo_ferramentas['Data de lançamento'] = pd.to_datetime(df_consumo_ferramentas['Data de lançamento'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 df_producao['Dt.lçto.'] = pd.to_datetime(df_producao['Dt.lçto.'])
# ----> 2 df_consumo_ferramentas['Data de lançamento'] = pd.to_datetime(df_consumo_ferramentas['Data de lançamento'])
#
# File ~\Desktop\repository\predicao_consumo_ferramenta\.venv\Lib\site-packages\pandas\core\tools\datetimes.py:1036, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1034             result = arg.tz_localize("utc")
#    1035 elif isinstance(arg, ABCSeries):
# -> 1036     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1037     if not cache_array.empty:
#    1038         result = arg.map(cache_array)
#
# ...

# %%
df_consumo_ferramentas[df_consumo_ferramentas['Data de lançamento'] == '-15281.86']
# Out:
#            Material  Qtd.  UM registro Data de lançamento
# 8893   31_000016837              201.0          -15281.86
# 63144  31_000016837              201.0          -15281.86

# %%
df_consumo_ferramentas.loc[range(8880,8894)]
# Out:
#           Material  Qtd.  UM registro Data de lançamento
# 8880  31_000025924               -1.0         2025-07-12
# 8881  31_000026158               -1.0         2025-07-12
# 8882  31_000000095               -1.0         2026-01-05
# 8883  31_000002148               -1.0         2026-01-05
# 8884  31_000007118               -2.0         2026-01-05
# 8885  31_000007543               -2.0         2026-01-05
# 8886  31_000011642               -2.0         2026-01-05
# 8887  31_000011887               -1.0         2026-01-05
# 8888  31_000012174               -1.0         2026-01-05
# 8889  31_000012176               -1.0         2026-01-05
# 8890  31_000012180               -1.0         2026-01-05
# 8891  31_000013410               -1.0         2026-01-05
# 8892  31_000014586               -1.0         2026-01-05
# 8893  31_000016837              201.0          -15281.86
