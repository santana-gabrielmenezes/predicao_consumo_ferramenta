# %%
import pandas as pd

# %%
df_producao = pd.read_csv('dados_originais/tb_producao_2022-05-01_2022-06-30.csv')
colunas = ['Material',
           'Qtd.boa confirm.',
           'Dt.lçto.']
df_producao = df_producao[colunas]
df_producao = df_producao.iloc[:-3]
df_producao
# Out:
#          Material  Qtd.boa confirm.    Dt.lçto.
# 0       1H65600T1                30  2022-05-01
# 1       1H65600T1                30  2022-05-01
# 2       1H65600T1                30  2022-05-01
# 3       1H65600T1                30  2022-05-01
# 4       1H65600T1                30  2022-05-01
# ...           ...               ...         ...
# 113030    6H76620                50  2022-06-30
# 113031    6H76620                50  2022-06-30
# 113032    6H76620                50  2022-06-30
# 113033    6H76620                50  2022-06-30
# 113034    6H76620                50  2022-06-30
#
# [113035 rows x 3 columns]

# %%
df_consumo_ferramenta = pd.read_csv('dados_originais/tb_consumo_ferramentas_2022-03-01_2026-02-28.csv')

# colunas = ['Material',
#            'Qtd.boa confirm.',
#            'Dt.lçto.']
# df_producao = df_producao[colunas]
df_consumo_ferramenta = df_consumo_ferramenta.iloc[:-7]
df_consumo_ferramenta
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_11604\1016197608.py:1: DtypeWarning: Columns (0: Tipo de movimento, 1: Nome do usuário, 2: Referência, 3: Pedido) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_consumo_ferramenta = pd.read_csv('dados_originais/tb_consumo_ferramentas_2022-03-01_2026-02-28.csv')
#             Material                     Texto breve material  Lote  \
# 0       31_000008769             INSERTO VNMG 12T304-NF IC907   NaN
# 1       31_000009799            INSERTO TNMG 160412-GH MC5125   NaN
# 2       31_000012717             INSERTO TCMT 110204-SM IC908   NaN
# 3       31_000020766                  PORTA FERR.TGDR 2525-3M   NaN
# 4       31_000022620                INSERTO NG2M 120RK KC5025   NaN
# ...              ...                                      ...   ...
# 166442  31_000028234            INSERTO SNMG 120408-SA UE6105   NaN
# 166443  31_000005305     INSERTO VCMT 160408-SM IC907 - ISCAR   NaN
# ...
