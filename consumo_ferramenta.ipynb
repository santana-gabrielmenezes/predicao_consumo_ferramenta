# %% [markdown]
# # Análise Exploratória de Dados (EDA)

# %%
# importa biblioteca necessária para EDA
import pandas as pd

# %%
# importa os dados
df_producao = pd.read_parquet('tb_producao_consolidado.parquet') # importa os dados de produção
df_consumo_ferramentas = pd.read_parquet('tb_consumo_ferramentas_consolidado.parquet') # importa os dados de consumo de ferramentas

print('--- Informações: df_producao ---' + '\n')
df_producao.info()

print('\n' + '-'*40 + '\n')

print('--- Informações: df_consumo_ferramentas ---' + '\n')
df_consumo_ferramentas.info()
# Out:
# --- Informações: df_producao ---
#
# <class 'pandas.DataFrame'>
# RangeIndex: 2945829 entries, 0 to 2945828
# Data columns (total 3 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Material          str
#  1   Qtd.boa confirm.  float64
#  2   Dt.lçto.          str
# dtypes: float64(1), str(2)
# memory usage: 120.0 MB
#
# ----------------------------------------
#
# --- Informações: df_consumo_ferramentas ---
#
# <class 'pandas.DataFrame'>
# RangeIndex: 166447 entries, 0 to 166446
# Data columns (total 3 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Material            166447 non-null  str
#  1   Qtd.  UM registro   166447 non-null  float64
#  2   Data de lançamento  166447 non-null  str
# dtypes: float64(1), str(2)
# memory usage: 7.3 MB

# %%
df_producao['decimal'] = df_producao['Qtd.boa confirm.'] % 1 == 0

# %%
df_producao[df_producao['decimal'] == False]
# Out:
#            Material  Qtd.boa confirm.    Dt.lçto.  decimal
# 953539   2H70350BA1           473.082  2023-07-13    False
# 953540   2H70350BA1           473.100  2023-07-13    False
# 953542   2H70350BA1           468.400  2023-07-13    False
# 955526          NaN          1944.582  13.07.2023    False
# 955528          NaN          1944.582  13.07.2023    False
# ...             ...               ...         ...      ...
# 2815868  2H70350BS1           478.400  2026-01-23    False
# 2815869  2H70350BS1           475.400  2026-01-28    False
# 2815870  2H89350BS1           437.400  2026-01-06    False
# 2815872  2H89350BS1           438.200  2026-01-21    False
# 2815873  2H89350BS1           437.800  2026-01-28    False
#
# [1439 rows x 4 columns]

# %%
df_producao['Material'].unique()
# Out:
# <ArrowStringArray>
# [    '1H65600U1',     '2A01742U1',     '2A02750U1',     '2G05601B2',
#     '2G05601FO2',     '2H23130U3',     '2H32242T2',     '2H32350B1',
#     '2H35232FO1',    '2H65160AC1',
#  ...
#  '2YA08920-B101',  '2D02740-A305',  '2H49240-A202', '2H69220-A201R',
#  '2H69220-A202R', '2H69220-B101R', '2YA03920-B101', '2YA08920-B103',
#  '2H76920-IE113', '3H82110-M209R']
# Length: 4599, dtype: str
